# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
a = tf.random.normal([2, 10])

# %%
sess =tf.Session()

# %%
out = sess.run(a)

# %%
x, y = out

# %%
plt.scatter(x,y)
plt.show()
